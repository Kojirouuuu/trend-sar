# %%
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import glob
import scipy.stats
from typing import List, Tuple, Dict
from matplotlib.ticker import MaxNLocator

# グラフの色指定
colors = ["tab:blue", "tab:orange", "tab:green", "tab:red", "tab:purple", "tab:brown", "tab:pink", "tab:gray", "tab:olive", "tab:cyan"]

# グラフ全体のフォント設定
plt.rcParams['font.family'] = 'serif'  # 全体のフォントをSerifに設定
plt.rcParams['mathtext.fontset'] = 'cm'  # 数式のフォントをComputer Modernに設定
plt.rcParams['mathtext.rm'] = 'serif'  # TeXの通常フォントをSerifに設定
plt.rcParams['font.size'] = 18  # デフォルトフォントサイズ
plt.rcParams['axes.labelsize'] = 18  # 軸ラベルのフォントサイズ
plt.rcParams['axes.titlesize'] = 22  # タイトルのフォントサイズ
plt.rcParams['legend.fontsize'] = 16  # 凡例のフォントサイズ
plt.rcParams['grid.color'] = 'gray'  # グリッドの色を薄い灰色に設定
plt.rcParams['grid.linestyle'] = ':'  # グリッドを点線に設定
plt.rcParams['grid.linewidth'] = 0.5  # グリッドの線幅を設定

# %%
"""
Load SIS simulation event times output by the Java App into a NumPy array.

- Input directory: `output/sis`
  - `metadata.csv` for parameters (itr, batch_num, c_list, lambda range)
  - `times_XX.txt` where each line is a comma-separated list of event times

- Output array `time`: shape = (len(cList), len(lambdaList), itr), dtype=object
  Each element is a 1D NumPy array of float64 event times for a single run.

Usage:
    from scripts.load_sis_time import load_time_array
    time, axes = load_time_array(output_dir="output/sis", batch_idx=0)
    # time.shape -> (C, L, itr)
    # axes["c_list"], axes["lambda_list"], axes["itr"]
"""

from __future__ import annotations

output_path = os.path.abspath(os.path.join('..', 'output/sis/ER/z=6/N=10000finalnonbfs'))
# output_path = os.path.abspath(os.path.join('..', 'java-project', 'output'))
if output_path not in sys.path:
    sys.path.append(output_path)

def _read_params(params_path: str) -> Dict[str, str]:
    params = pd.read_csv(params_path)
    network_type = params['networkType'].values[0]
    N = params['N'].values[0]
    k_ave = params['k_ave'].values[0]
    gamma = params['gamma'].values[0]
    tmax = params['tmax'].values[0]
    c_list = params['cList'].values[0]
    rho0List = params['rho0List'].values[0]
    lambda_values = params['lambdaList'].values[0]
    seed = params['seed'].values[0]
    itr = params['itr'].values[0]
    batchNum = params['batchNum'].values[0]

    try:
        c_list = c_list.split(":")
        c_list = [float(c) for c in c_list]
    except:
        c_list = [float(c_list)]

    rho0List = rho0List.split(":")
    rho0List = [float(rho0) for rho0 in rho0List]

    lamb_values = lambda_values.split(":")
    lamb_values = [float(lamb) for lamb in lamb_values]

    return network_type, N, k_ave, gamma, tmax, seed, itr, batchNum, c_list, lamb_values, rho0List


def _read_metadata(meta_path: str = os.path.join(output_path, "metadata.csv")) -> Dict[str, str]:
    """Read key,value style metadata where values may contain commas.

    This parser splits each line at the first comma only.
    Returns a dict of raw string values.
    """
    meta: Dict[str, str] = {}
    with open(meta_path, "r", encoding="utf-8") as f:
        # skip header if present
        header = f.readline()
        if "," not in header:
            # Unexpected; treat as data line
            key, val = header.strip().split(",", 1)
            meta[key.strip()] = val.strip()
        for line in f:
            line = line.rstrip("\n")
            if not line:
                continue
            if "," not in line:
                continue
            key, val = line.split(",", 1)
            meta[key.strip()] = val.strip()
    return meta


def load_batch(output_dir: str, batch_idx: int, isFinal: bool = False) -> Tuple[np.ndarray, np.ndarray]:
    params_path = os.path.join(output_dir, "params.csv")
    if not os.path.exists(params_path):
        raise FileNotFoundError(f"params.csv not found in {output_dir}")

    _, _, _, _, _, _, itr, _, c_list, lambda_values, rho0List = _read_params(params_path)

    R, C, L = len(rho0List), len(c_list), len(lambda_values)
    expected = R * C * L * itr

    times_file = os.path.join(output_dir, f"times_{batch_idx:02d}.txt")
    infected_file = os.path.join(output_dir, f"infected_num_{batch_idx:02d}.txt")
    if not os.path.exists(times_file) or not os.path.exists(infected_file):
        raise FileNotFoundError(f"Missing times or infected file for batch {batch_idx:02d}")

    time = np.empty((R, C, L, itr), dtype=object)
    infected = np.empty((R, C, L, itr), dtype=object)

    # Initialize with empty arrays to avoid uninitialized slots
    for r in range(R):
        for c in range(C):
            for l in range(L):
                for i in range(itr):
                    time[r, c, l, i] = np.array([], dtype=float)
                    infected[r, c, l, i] = np.array([], dtype=int)

    # Iterate paired lines; stop when either file ends
    tcount = icount = 0
    with open(times_file, "r", encoding="utf-8", errors="ignore") as tf, open(infected_file, "r", encoding="utf-8", errors="ignore") as inf:
        while True:
            tline = tf.readline()
            iline = inf.readline()
            if not tline or not iline:
                break
            ts = tline.strip()
            is_ = iline.strip()
            tarr = np.fromstring(ts, sep=",", dtype=float) if ts else np.array([], dtype=float)
            iarr = np.fromstring(is_, sep=",", dtype=int) if is_ else np.array([], dtype=int)

            flat_idx = tcount  # counts paired lines
            if flat_idx >= expected:
                break
            eIdx = flat_idx // (C * L * itr)
            rem = flat_idx % (C * L * itr)
            cIdx = rem // (L * itr)
            rem = rem % (L * itr)
            lIdx = rem // itr
            itIdx = rem % itr
            time[eIdx, cIdx, lIdx, itIdx] = tarr
            infected[eIdx, cIdx, lIdx, itIdx] = iarr
            tcount += 1
            icount += 1

    # If files contain additional lines beyond expected, ignore extras silently.
    # If fewer lines, warn but do not raise.
    if tcount < expected or icount < expected:
        missing = expected - min(tcount, icount)
        print(
            f"[WARN] Batch {batch_idx:02d}: filled {min(tcount, icount)} / {expected} runs; "
            f"{missing} missing. Unfilled slots remain empty arrays.")

    if not isFinal:
        return time, infected
    else:
        return time[-1], infected[-1]

def load(path: str = output_path, max_file_num: int = 1e5, isFinal: bool = False) -> Tuple[np.ndarray, np.ndarray, Dict[str, object]]:
    network_type, N, k_ave, gamma, tmax, seed, itr, batchNum, c_list, lamb_values, rho0List = _read_params(os.path.join(path, "params.csv"))

    valid_batch_idx = []
    valid_file_num = 0

    for batch_idx in range(batchNum):
        if os.path.exists(os.path.join(path, f"times_{batch_idx:02d}.txt")) and os.path.exists(os.path.join(path, f"infected_num_{batch_idx:02d}.txt")):
            print(f"idx: {batch_idx}, {valid_file_num}th file is found")
            valid_batch_idx.append(batch_idx)
            valid_file_num += 1
            if valid_file_num >= max_file_num:
                break

    total_itr = len(valid_batch_idx) * itr
    shape = (len(rho0List), len(c_list), len(lamb_values), total_itr)
    times_all = np.zeros(shape, dtype=object)
    infected_num_all = np.zeros(shape, dtype=object)  # 修正: dtype=object

    print("")
    print(f"Lets load {valid_file_num} files!")

    for batch_idx in valid_batch_idx:
        print(f" --> Loading {batch_idx}th file...")
        times, infected_num = load_batch(path, batch_idx, isFinal)
        times_all[:, :, :, batch_idx * itr : (batch_idx + 1) * itr] = times
        infected_num_all[:, :, :, batch_idx * itr : (batch_idx + 1) * itr] = infected_num

    axes = {
        "network_type": network_type,
        "N": N,
        "k_ave": k_ave,
        "gamma": gamma,
        "tmax": tmax,
        "seed": seed,
        "total_itr": total_itr,
        "c_list": c_list,
        "rho0List": rho0List,
        "lamb_values": lamb_values,
    }

    return times_all, infected_num_all, axes

# %%
# y(Theta)を計算する関数
def y_SIS(deg_list, pk, lamb, gamma, Theta, c=0):
    # 平均次数 <k> = Σ k*p(k)
    k_ave = np.sum(deg_list * pk)
    if k_ave == 0:
        return -Theta

    y = 0
    for k, p in zip(deg_list, pk):
        gamma_bar = gamma / (1 + c * k * Theta)
        y += k * p * lamb * k * Theta / (gamma_bar + lamb * k * Theta)
    
    y /= k_ave
    y -= Theta
    return y

# y'(Theta) = dy/dTheta を計算する関数
def dy_dTheta_SIS(deg_list, pk, lamb, gamma, Theta, c=0.0):
    k_ave = np.sum(deg_list * pk)
    if k_ave == 0:
        return -1.0
    dy = 0.0
    for k, p in zip(deg_list, pk):
        B = gamma + lamb * k * Theta * (1.0 + c * k * Theta)  # 正しい分母
        if B == 0:
            return np.nan
        fprime = (lamb * gamma * k * (1.0 + 2.0 * c * k * Theta)) / (B ** 2)
        dy += k * p * fprime
    dy /= k_ave
    dy -= 1.0
    return dy


# ニュートン法を実装した関数
def newton_method(deg_list, pk, lamb, gamma, Theta_initial=0.9, tolerance=1e-16, max_iter=100, c=0):
    """
    ニュートン法を用いて y_SIS(Theta) = 0 となるThetaを探す
    """
    Theta = Theta_initial
    for i in range(max_iter):
        y_val = y_SIS(deg_list, pk, lamb, gamma, Theta, c)
        
        # yが十分に0に近ければ終了
        if abs(y_val) < tolerance:
            return Theta

        dy_val = dy_dTheta_SIS(deg_list, pk, lamb, gamma, Theta, c)

        # 導関数が0に近く、更新が発散しそうな場合は終了
        if abs(dy_val) < 1e-10:
            # print(f"Warning: Derivative is too small at lambda={lamb}, Theta={Theta}. Stopping.")
            return Theta

        # ニュートン法の更新式
        Theta_new = Theta - y_val / dy_val
        
        # 更新量が十分に小さくなれば終了
        if abs(Theta_new - Theta) < tolerance:
            return Theta_new
            
        Theta = Theta_new
        
    # print(f"Warning: Newton's method did not converge for lambda={lamb} within {max_iter} iterations.")
    return Theta

def theta_to_I(deg_list, pk, lamb, gamma, Theta, c=0):
    k_ave = np.sum(deg_list * pk)
    if k_ave == 0:
        return 0
    I = 0
    for k, p in zip(deg_list, pk):
        gamma_bar = gamma / (1 + c * k * Theta)
        I += k * p * lamb * k * Theta / (gamma_bar + lamb * k * Theta)
    I /= k_ave
    return I

def theta_symbolic_RR_numeric(lamb: float, K: float, gamma: float, c: float) -> float:
    """
    RR（正則）ネットワークの閉形式解を用いて Theta(λ) を数値的に返す。
    - c=0 のとき: Theta = max(0, 1 - gamma/(lambda*K))
    - c>0 のとき: 2次方程式の正の根を使用。
    物理的制約に合わせて [0,1] にクリップする。
    """
    if lamb <= 0:
        return 0.0
    if c == 0:
        theta = 1.0 - gamma / (lamb * K)
        return float(np.clip(theta, 0.0, 1.0))
    a = c * K
    b = 1.0 - c * K
    c0 = gamma / (lamb * K) - 1.0
    D = b * b - 4.0 * a * c0
    if D < 0:
        return 0.0
    theta = (-b + np.sqrt(D)) / (2.0 * a)
    return float(np.clip(theta, 0.0, 1.0))

# %%
times_all, infected_num_all, axes = load()
meta = _read_metadata()
network_type = axes["network_type"]
N = axes["N"]
k_ave = axes["k_ave"]
gamma = axes["gamma"]
tmax = axes["tmax"]
seed = axes["seed"]
total_itr = axes["total_itr"]
c_list = axes["c_list"]
rho0List = axes["rho0List"]
lamb_values = axes["lamb_values"]
# Out:
# idx: 0, 0th file is found
# idx: 1, 1th file is found
# idx: 2, 2th file is found
# idx: 3, 3th file is found
# idx: 4, 4th file is found
# idx: 5, 5th file is found
# idx: 6, 6th file is found
# idx: 7, 7th file is found
# idx: 8, 8th file is found
# idx: 9, 9th file is found
# idx: 10, 10th file is found
# idx: 11, 11th file is found
# idx: 12, 12th file is found
# idx: 13, 13th file is found
# idx: 14, 14th file is found
# idx: 15, 15th file is found
# idx: 16, 16th file is found
# idx: 17, 17th file is found
# idx: 18, 18th file is found
# idx: 19, 19th file is found
# idx: 20, 20th file is found
# idx: 21, 21th file is found
# idx: 22, 22th file is found
# idx: 23, 23th file is found
# idx: 24, 24th file is found
# idx: 25, 25th file is found
# idx: 26, 26th file is found
# idx: 27, 27th file is found
# idx: 28, 28th file is found
# idx: 29, 29th file is found
# idx: 30, 30th file is found
# idx: 31, 31th file is found
# idx: 32, 32th file is found
# idx: 33, 33th file is found
# idx: 34, 34th file is found
# idx: 35, 35th file is found
# idx: 36, 36th file is found
# idx: 37, 37th file is found
# idx: 38, 38th file is found
# idx: 39, 39th file is found
# idx: 40, 40th file is found
# idx: 41, 41th file is found
# idx: 42, 42th file is found
# idx: 43, 43th file is found
# idx: 44, 44th file is found
# idx: 45, 45th file is found
# idx: 46, 46th file is found
# idx: 47, 47th file is found
# idx: 48, 48th file is found
# idx: 49, 49th file is found
# idx: 50, 50th file is found
# idx: 51, 51th file is found
# idx: 52, 52th file is found
# idx: 53, 53th file is found
# idx: 54, 54th file is found
# idx: 55, 55th file is found
# idx: 56, 56th file is found
# idx: 57, 57th file is found
# idx: 58, 58th file is found
# idx: 59, 59th file is found
# idx: 60, 60th file is found
# idx: 61, 61th file is found
# idx: 62, 62th file is found
# idx: 63, 63th file is found
# idx: 64, 64th file is found
# idx: 65, 65th file is found
# idx: 66, 66th file is found
# idx: 67, 67th file is found
# idx: 68, 68th file is found
# idx: 69, 69th file is found
# idx: 70, 70th file is found
# idx: 71, 71th file is found
# idx: 72, 72th file is found
# idx: 73, 73th file is found
# idx: 74, 74th file is found
# idx: 75, 75th file is found
# idx: 76, 76th file is found
# idx: 77, 77th file is found
# idx: 78, 78th file is found
# idx: 79, 79th file is found
# idx: 80, 80th file is found
# idx: 81, 81th file is found
# idx: 82, 82th file is found
# idx: 83, 83th file is found
# idx: 84, 84th file is found
# idx: 85, 85th file is found
# idx: 86, 86th file is found
# idx: 87, 87th file is found
# idx: 88, 88th file is found
# idx: 89, 89th file is found
# idx: 90, 90th file is found
# idx: 91, 91th file is found
# idx: 92, 92th file is found
# idx: 93, 93th file is found
# idx: 94, 94th file is found
# idx: 95, 95th file is found
# idx: 96, 96th file is found
# idx: 97, 97th file is found
# idx: 98, 98th file is found
# idx: 99, 99th file is found
#
# Lets load 100 files!
#  --> Loading 0th file...
#  --> Loading 1th file...
#  --> Loading 2th file...
#  --> Loading 3th file...
#  --> Loading 4th file...
#  --> Loading 5th file...
#  --> Loading 6th file...
#  --> Loading 7th file...
#  --> Loading 8th file...
#  --> Loading 9th file...
#  --> Loading 10th file...
#  --> Loading 11th file...
#  --> Loading 12th file...
#  --> Loading 13th file...
#  --> Loading 14th file...
#  --> Loading 15th file...
#  --> Loading 16th file...
#  --> Loading 17th file...
#  --> Loading 18th file...
#  --> Loading 19th file...
#  --> Loading 20th file...
#  --> Loading 21th file...
#  --> Loading 22th file...
#  --> Loading 23th file...
#  --> Loading 24th file...
#  --> Loading 25th file...
#  --> Loading 26th file...
#  --> Loading 27th file...
#  --> Loading 28th file...
#  --> Loading 29th file...
#  --> Loading 30th file...
#  --> Loading 31th file...
#  --> Loading 32th file...
#  --> Loading 33th file...
#  --> Loading 34th file...
#  --> Loading 35th file...
#  --> Loading 36th file...
#  --> Loading 37th file...
#  --> Loading 38th file...
#  --> Loading 39th file...
#  --> Loading 40th file...
#  --> Loading 41th file...
#  --> Loading 42th file...
#  --> Loading 43th file...
#  --> Loading 44th file...
#  --> Loading 45th file...
#  --> Loading 46th file...
#  --> Loading 47th file...
#  --> Loading 48th file...
#  --> Loading 49th file...
#  --> Loading 50th file...
#  --> Loading 51th file...
#  --> Loading 52th file...
#  --> Loading 53th file...
#  --> Loading 54th file...
#  --> Loading 55th file...
#  --> Loading 56th file...
#  --> Loading 57th file...
#  --> Loading 58th file...
#  --> Loading 59th file...
#  --> Loading 60th file...
#  --> Loading 61th file...
#  --> Loading 62th file...
#  --> Loading 63th file...
#  --> Loading 64th file...
#  --> Loading 65th file...
#  --> Loading 66th file...
#  --> Loading 67th file...
#  --> Loading 68th file...
#  --> Loading 69th file...
#  --> Loading 70th file...
#  --> Loading 71th file...
#  --> Loading 72th file...
#  --> Loading 73th file...
#  --> Loading 74th file...
#  --> Loading 75th file...
#  --> Loading 76th file...
#  --> Loading 77th file...
#  --> Loading 78th file...
#  --> Loading 79th file...
#  --> Loading 80th file...
#  --> Loading 81th file...
#  --> Loading 82th file...
#  --> Loading 83th file...
#  --> Loading 84th file...
#  --> Loading 85th file...
#  --> Loading 86th file...
#  --> Loading 87th file...
#  --> Loading 88th file...
#  --> Loading 89th file...
#  --> Loading 90th file...
#  --> Loading 91th file...
#  --> Loading 92th file...
#  --> Loading 93th file...
#  --> Loading 94th file...
#  --> Loading 95th file...
#  --> Loading 96th file...
#  --> Loading 97th file...
#  --> Loading 98th file...
#  --> Loading 99th file...

# %%
print("==== shape ====")
print(times_all.shape)
print(infected_num_all.shape)

print("")
print("==== params ====")
print(f"network_type: {network_type}")
print(f"N: {N}")
print(f"k_ave: {k_ave}")
print(f"gamma: {gamma}")
print(f"tmax: {tmax}")
print(f"seed: {seed}")
print(f"total_itr: {total_itr}")

print("")
print("==== meta data ====")
for key, value in meta.items():
    print(f"{key}: {value}")
# Out:
# ==== shape ====
# (3, 1, 51, 1000)
# (3, 1, 51, 1000)
#
# ==== params ====
# network_type: ER
# N: 10000
# k_ave: 6
# gamma: 1.0
# tmax: 2000.0
# seed: 0.0
# total_itr: 1000
#
# ==== meta data ====
# start_time: 2025-09-13 20:12:52
# end_time: 2025-09-14 02:38:02
# duration_seconds: 23110.426
# network_type: ER
# runs_per_batch: 510
# total_runs: 51000
# seed_base: 0
# os_name: Mac OS X
# os_version: 15.3.1
# java_version: 24.0.2
# java_vendor: Homebrew
# cpu_cores: 10
# total_memory_mb: 340
# max_memory_mb: 4096

# %%
test_lamb_idx_list = [0, 2, 10, 20, 30]
test_lamb_idx_list = np.array(test_lamb_idx_list, dtype=int)

lamb_size = len(lamb_values)
lamb_idx_list = []
for i in test_lamb_idx_list:
    if i < lamb_size:
        lamb_idx_list.append(i)

lamb_idx_list = np.array(lamb_idx_list)

# %%
threshold = 0

last_I = np.zeros((len(rho0List), len(c_list), len(lamb_values), total_itr))
valid_last_I = np.zeros((len(rho0List), len(c_list), len(lamb_values)))
valid_num = np.zeros((len(rho0List), len(c_list), len(lamb_values)))
for rho0_idx in range(len(rho0List)):
    for c_idx in range(len(c_list)):
        for lamb_idx in range(len(lamb_values)):
            valid = []
            non_valid = []
            for itr_idx in range(total_itr):
                if infected_num_all[rho0_idx, c_idx, lamb_idx, itr_idx].size == 0:
                    print(f"Error: infected_num_all[{rho0_idx}, {c_idx}, {lamb_idx}, {itr_idx}] is None")
                    continue
                I = infected_num_all[rho0_idx, c_idx, lamb_idx, itr_idx]
                if I > threshold:
                    valid.append(I)
                    valid_num[rho0_idx, c_idx, lamb_idx] += 1
                else:
                    non_valid.append(I)
            if len(valid) > 0:
                valid_last_I[rho0_idx, c_idx, lamb_idx] = np.mean(valid)
            else:
                valid_last_I[rho0_idx, c_idx, lamb_idx] = np.mean(non_valid)

# %%
colors = ["tab:red", "tab:purple", "tab:blue"]

# %%
fig, axes = plt.subplots(1, len(c_list), figsize=(7 * len(c_list), 6), sharey=True, squeeze=False)

delta = 0.05

for c_idx, c in enumerate(c_list):
    ax = axes[0, c_idx]
    # to_Is = np.zeros(len(lamb_values_for_theory))
    # for lamb_idx, lamb in enumerate(lamb_values_for_theory):
    #     to_I = theta_to_I(deg_list, pk, lamb, gamma, theta_all[c_idx, lamb_idx], c=c)
    #     to_Is[lamb_idx] = to_I
    # axes[c_idx].plot(lamb_values_for_theory, to_Is, color=colors[0], label="Theory", linestyle="--", linewidth=0.5)

    for rho0_idx in range(len(rho0List)):
        rho0 = rho0List[rho0_idx]
        valid_mean_I = valid_last_I[rho0_idx, c_idx, :]
        ax.plot(lamb_values, valid_mean_I/N, linestyle="-", color=colors[rho0_idx], marker="o", markersize=6, markerfacecolor="none", markeredgecolor=colors[rho0_idx])
        # axes[c_idx].plot(lamb_values, valid_mean_I/(2 * N), label=f"edge={edge_num}", linestyle="", marker="o", markersize=6, markerfacecolor="none", markeredgecolor=colors[e_idx])

    # ax.legend()
    ax.grid(True, linestyle=":", alpha=0.5)
    # ax.set_title(rf"$c={c}$")
    ax.set_xlabel(r"$\lambda$")
    # if c_idx == 0:
    #     ax.set_ylabel(rf"$I(t={tmax})$")
    # axes[c_idx].set_xlim(0.10, 0.11)
    # ax.set_ylim(0-delta, 1+delta)
    ax.xaxis.set_major_locator(MaxNLocator(nbins=5))

# fig.suptitle(rf"Network$: {network_type}, N={N}, \left<k\right>={k_ave}, $tmax$={tmax}$")
fig.tight_layout()

base = "fig"
suf = 0
while os.path.exists(f"{base}_{suf}.png"):
    suf += 1
# plt.savefig(f"{base}_{suf}.png", dpi=300)
plt.show()

# %%
output_path = os.path.abspath(os.path.join('..', 'output/sis/BA/z=6/N=10000finalnonbfssupersample'))
times_all2, infected_num_all2, axes2 = load(output_path)
meta = _read_metadata()
network_type = axes2["network_type"]
N = axes2["N"]
k_ave = axes2["k_ave"]
gamma = axes2["gamma"]
tmax = axes2["tmax"]
seed = axes2["seed"]
total_itr2 = axes2["total_itr"]
c_list2 = axes2["c_list"]
rho0List2 = axes2["rho0List"]
lamb_values2 = axes2["lamb_values"]
# Out:
# idx: 0, 0th file is found
# idx: 1, 1th file is found
# idx: 2, 2th file is found
# idx: 3, 3th file is found
# idx: 4, 4th file is found
# idx: 5, 5th file is found
# idx: 6, 6th file is found
# idx: 7, 7th file is found
# idx: 8, 8th file is found
# idx: 9, 9th file is found
# idx: 10, 10th file is found
# idx: 11, 11th file is found
# idx: 12, 12th file is found
# idx: 13, 13th file is found
# idx: 14, 14th file is found
# idx: 15, 15th file is found
# idx: 16, 16th file is found
# idx: 17, 17th file is found
# idx: 18, 18th file is found
# idx: 19, 19th file is found
# idx: 20, 20th file is found
# idx: 21, 21th file is found
# idx: 22, 22th file is found
# idx: 23, 23th file is found
# idx: 24, 24th file is found
# idx: 25, 25th file is found
# idx: 26, 26th file is found
# idx: 27, 27th file is found
# idx: 28, 28th file is found
# idx: 29, 29th file is found
# idx: 30, 30th file is found
# idx: 31, 31th file is found
# idx: 32, 32th file is found
# idx: 33, 33th file is found
# idx: 34, 34th file is found
# idx: 35, 35th file is found
# idx: 36, 36th file is found
# idx: 37, 37th file is found
# idx: 38, 38th file is found
# idx: 39, 39th file is found
# idx: 40, 40th file is found
# idx: 41, 41th file is found
# idx: 42, 42th file is found
# idx: 43, 43th file is found
# idx: 44, 44th file is found
# idx: 45, 45th file is found
# idx: 46, 46th file is found
# idx: 47, 47th file is found
# idx: 48, 48th file is found
# idx: 49, 49th file is found
# idx: 50, 50th file is found
# idx: 51, 51th file is found
# idx: 52, 52th file is found
# idx: 53, 53th file is found
# idx: 54, 54th file is found
# idx: 55, 55th file is found
# idx: 56, 56th file is found
# idx: 57, 57th file is found
# idx: 58, 58th file is found
# idx: 59, 59th file is found
# idx: 60, 60th file is found
# idx: 61, 61th file is found
# idx: 62, 62th file is found
# idx: 63, 63th file is found
# idx: 64, 64th file is found
# idx: 65, 65th file is found
# idx: 66, 66th file is found
# idx: 67, 67th file is found
# idx: 68, 68th file is found
# idx: 69, 69th file is found
# idx: 70, 70th file is found
# idx: 71, 71th file is found
# idx: 72, 72th file is found
# idx: 73, 73th file is found
# idx: 74, 74th file is found
# idx: 75, 75th file is found
# idx: 76, 76th file is found
# idx: 77, 77th file is found
# idx: 78, 78th file is found
# idx: 79, 79th file is found
# idx: 80, 80th file is found
# idx: 81, 81th file is found
# idx: 82, 82th file is found
# idx: 83, 83th file is found
# idx: 84, 84th file is found
# idx: 85, 85th file is found
# idx: 86, 86th file is found
# idx: 87, 87th file is found
# idx: 88, 88th file is found
# idx: 89, 89th file is found
# idx: 90, 90th file is found
# idx: 91, 91th file is found
# idx: 92, 92th file is found
# idx: 93, 93th file is found
# idx: 94, 94th file is found
# idx: 95, 95th file is found
# idx: 96, 96th file is found
# idx: 97, 97th file is found
# idx: 98, 98th file is found
# idx: 99, 99th file is found
# idx: 100, 100th file is found
# idx: 101, 101th file is found
# idx: 102, 102th file is found
# idx: 103, 103th file is found
# idx: 104, 104th file is found
# idx: 105, 105th file is found
# idx: 106, 106th file is found
# idx: 107, 107th file is found
# idx: 108, 108th file is found
# idx: 109, 109th file is found
# idx: 110, 110th file is found
# idx: 111, 111th file is found
# idx: 112, 112th file is found
# idx: 113, 113th file is found
# idx: 114, 114th file is found
# idx: 115, 115th file is found
# idx: 116, 116th file is found
# idx: 117, 117th file is found
# idx: 118, 118th file is found
# idx: 119, 119th file is found
# idx: 120, 120th file is found
# idx: 121, 121th file is found
# idx: 122, 122th file is found
# idx: 123, 123th file is found
# idx: 124, 124th file is found
# idx: 125, 125th file is found
# idx: 126, 126th file is found
# idx: 127, 127th file is found
# idx: 128, 128th file is found
# idx: 129, 129th file is found
# idx: 130, 130th file is found
# idx: 131, 131th file is found
# idx: 132, 132th file is found
# idx: 133, 133th file is found
# idx: 134, 134th file is found
# idx: 135, 135th file is found
# idx: 136, 136th file is found
# idx: 137, 137th file is found
# idx: 138, 138th file is found
# idx: 139, 139th file is found
# idx: 140, 140th file is found
# idx: 141, 141th file is found
# idx: 142, 142th file is found
# idx: 143, 143th file is found
# idx: 144, 144th file is found
# idx: 145, 145th file is found
# idx: 146, 146th file is found
# idx: 147, 147th file is found
# idx: 148, 148th file is found
# idx: 149, 149th file is found
# idx: 150, 150th file is found
# idx: 151, 151th file is found
# idx: 152, 152th file is found
# idx: 153, 153th file is found
# idx: 154, 154th file is found
# idx: 155, 155th file is found
# idx: 156, 156th file is found
# idx: 157, 157th file is found
# idx: 158, 158th file is found
# idx: 159, 159th file is found
# idx: 160, 160th file is found
# idx: 161, 161th file is found
# idx: 162, 162th file is found
# idx: 163, 163th file is found
# idx: 164, 164th file is found
# idx: 165, 165th file is found
# idx: 166, 166th file is found
# idx: 167, 167th file is found
# idx: 168, 168th file is found
# idx: 169, 169th file is found
# idx: 170, 170th file is found
# idx: 171, 171th file is found
# idx: 172, 172th file is found
# idx: 173, 173th file is found
# idx: 174, 174th file is found
# idx: 175, 175th file is found
# idx: 176, 176th file is found
# idx: 177, 177th file is found
# idx: 178, 178th file is found
# idx: 179, 179th file is found
# idx: 180, 180th file is found
# idx: 181, 181th file is found
# idx: 182, 182th file is found
# idx: 183, 183th file is found
# idx: 184, 184th file is found
# idx: 185, 185th file is found
# idx: 186, 186th file is found
# idx: 187, 187th file is found
# idx: 188, 188th file is found
# idx: 189, 189th file is found
# idx: 190, 190th file is found
# idx: 191, 191th file is found
# idx: 192, 192th file is found
# idx: 193, 193th file is found
# idx: 194, 194th file is found
# idx: 195, 195th file is found
# idx: 196, 196th file is found
# idx: 197, 197th file is found
# idx: 198, 198th file is found
# idx: 199, 199th file is found
# idx: 200, 200th file is found
# idx: 201, 201th file is found
# idx: 202, 202th file is found
# idx: 203, 203th file is found
# idx: 204, 204th file is found
# idx: 205, 205th file is found
# idx: 206, 206th file is found
# idx: 207, 207th file is found
# idx: 208, 208th file is found
# idx: 209, 209th file is found
# idx: 210, 210th file is found
# idx: 211, 211th file is found
# idx: 212, 212th file is found
# idx: 213, 213th file is found
# idx: 214, 214th file is found
# idx: 215, 215th file is found
# idx: 216, 216th file is found
# idx: 217, 217th file is found
# idx: 218, 218th file is found
# idx: 219, 219th file is found
# idx: 220, 220th file is found
# idx: 221, 221th file is found
# idx: 222, 222th file is found
# idx: 223, 223th file is found
# idx: 224, 224th file is found
# idx: 225, 225th file is found
# idx: 226, 226th file is found
# idx: 227, 227th file is found
# idx: 228, 228th file is found
# idx: 229, 229th file is found
# idx: 230, 230th file is found
# idx: 231, 231th file is found
# idx: 232, 232th file is found
# idx: 233, 233th file is found
# idx: 234, 234th file is found
# idx: 235, 235th file is found
# idx: 236, 236th file is found
# idx: 237, 237th file is found
# idx: 238, 238th file is found
# idx: 239, 239th file is found
# idx: 240, 240th file is found
# idx: 241, 241th file is found
# idx: 242, 242th file is found
# idx: 243, 243th file is found
# idx: 244, 244th file is found
# idx: 245, 245th file is found
# idx: 246, 246th file is found
# idx: 247, 247th file is found
# idx: 248, 248th file is found
# idx: 249, 249th file is found
# idx: 250, 250th file is found
# idx: 251, 251th file is found
# idx: 252, 252th file is found
# idx: 253, 253th file is found
# idx: 254, 254th file is found
# idx: 255, 255th file is found
# idx: 256, 256th file is found
# idx: 257, 257th file is found
# idx: 258, 258th file is found
# idx: 259, 259th file is found
# idx: 260, 260th file is found
# idx: 261, 261th file is found
# idx: 262, 262th file is found
# idx: 263, 263th file is found
# idx: 264, 264th file is found
# idx: 265, 265th file is found
# idx: 266, 266th file is found
# idx: 267, 267th file is found
# idx: 268, 268th file is found
# idx: 269, 269th file is found
# idx: 270, 270th file is found
# idx: 271, 271th file is found
# idx: 272, 272th file is found
# idx: 273, 273th file is found
# idx: 274, 274th file is found
# idx: 275, 275th file is found
# idx: 276, 276th file is found
# idx: 277, 277th file is found
# idx: 278, 278th file is found
# idx: 279, 279th file is found
# idx: 280, 280th file is found
# idx: 281, 281th file is found
# idx: 282, 282th file is found
# idx: 283, 283th file is found
# idx: 284, 284th file is found
# idx: 285, 285th file is found
# idx: 286, 286th file is found
# idx: 287, 287th file is found
# idx: 288, 288th file is found
# idx: 289, 289th file is found
# idx: 290, 290th file is found
# idx: 291, 291th file is found
# idx: 292, 292th file is found
# idx: 293, 293th file is found
# idx: 294, 294th file is found
# idx: 295, 295th file is found
# idx: 296, 296th file is found
# idx: 297, 297th file is found
# idx: 298, 298th file is found
# idx: 299, 299th file is found
# idx: 300, 300th file is found
# idx: 301, 301th file is found
# idx: 302, 302th file is found
# idx: 303, 303th file is found
# idx: 304, 304th file is found
# idx: 305, 305th file is found
# idx: 306, 306th file is found
# idx: 307, 307th file is found
# idx: 308, 308th file is found
# idx: 309, 309th file is found
# idx: 310, 310th file is found
# idx: 311, 311th file is found
# idx: 312, 312th file is found
# idx: 313, 313th file is found
# idx: 314, 314th file is found
# idx: 315, 315th file is found
# idx: 316, 316th file is found
# idx: 317, 317th file is found
# idx: 318, 318th file is found
# idx: 319, 319th file is found
# idx: 320, 320th file is found
# idx: 321, 321th file is found
# idx: 322, 322th file is found
# idx: 323, 323th file is found
# idx: 324, 324th file is found
# idx: 325, 325th file is found
# idx: 326, 326th file is found
# idx: 327, 327th file is found
# idx: 328, 328th file is found
# idx: 329, 329th file is found
# idx: 330, 330th file is found
# idx: 331, 331th file is found
# idx: 332, 332th file is found
# idx: 333, 333th file is found
# idx: 334, 334th file is found
# idx: 335, 335th file is found
# idx: 336, 336th file is found
# idx: 337, 337th file is found
# idx: 338, 338th file is found
# idx: 339, 339th file is found
# idx: 340, 340th file is found
# idx: 341, 341th file is found
# idx: 342, 342th file is found
# idx: 343, 343th file is found
# idx: 344, 344th file is found
# idx: 345, 345th file is found
# idx: 346, 346th file is found
# idx: 347, 347th file is found
# idx: 348, 348th file is found
# idx: 349, 349th file is found
# idx: 350, 350th file is found
# idx: 351, 351th file is found
# idx: 352, 352th file is found
# idx: 353, 353th file is found
# idx: 354, 354th file is found
# idx: 355, 355th file is found
# idx: 356, 356th file is found
# idx: 357, 357th file is found
# idx: 358, 358th file is found
# idx: 359, 359th file is found
# idx: 360, 360th file is found
# idx: 361, 361th file is found
# idx: 362, 362th file is found
# idx: 363, 363th file is found
# idx: 364, 364th file is found
# idx: 365, 365th file is found
# idx: 366, 366th file is found
# idx: 367, 367th file is found
# idx: 368, 368th file is found
# idx: 369, 369th file is found
# idx: 370, 370th file is found
# idx: 371, 371th file is found
# idx: 372, 372th file is found
# idx: 373, 373th file is found
# idx: 374, 374th file is found
# idx: 375, 375th file is found
# idx: 376, 376th file is found
# idx: 377, 377th file is found
# idx: 378, 378th file is found
# idx: 379, 379th file is found
# idx: 380, 380th file is found
# idx: 381, 381th file is found
# idx: 382, 382th file is found
# idx: 383, 383th file is found
# idx: 384, 384th file is found
# idx: 385, 385th file is found
# idx: 386, 386th file is found
# idx: 387, 387th file is found
# idx: 388, 388th file is found
# idx: 389, 389th file is found
# idx: 390, 390th file is found
# idx: 391, 391th file is found
# idx: 392, 392th file is found
# idx: 393, 393th file is found
# idx: 394, 394th file is found
# idx: 395, 395th file is found
# idx: 396, 396th file is found
# idx: 397, 397th file is found
# idx: 398, 398th file is found
# idx: 399, 399th file is found
# idx: 400, 400th file is found
# idx: 401, 401th file is found
# idx: 402, 402th file is found
# idx: 403, 403th file is found
# idx: 404, 404th file is found
# idx: 405, 405th file is found
# idx: 406, 406th file is found
# idx: 407, 407th file is found
# idx: 408, 408th file is found
# idx: 409, 409th file is found
# idx: 410, 410th file is found
# idx: 411, 411th file is found
# idx: 412, 412th file is found
# idx: 413, 413th file is found
# idx: 414, 414th file is found
# idx: 415, 415th file is found
# idx: 416, 416th file is found
# idx: 417, 417th file is found
# idx: 418, 418th file is found
# idx: 419, 419th file is found
# idx: 420, 420th file is found
# idx: 421, 421th file is found
# idx: 422, 422th file is found
# idx: 423, 423th file is found
# idx: 424, 424th file is found
# idx: 425, 425th file is found
# idx: 426, 426th file is found
# idx: 427, 427th file is found
# idx: 428, 428th file is found
# idx: 429, 429th file is found
# idx: 430, 430th file is found
# idx: 431, 431th file is found
# idx: 432, 432th file is found
# idx: 433, 433th file is found
# idx: 434, 434th file is found
# idx: 435, 435th file is found
# idx: 436, 436th file is found
# idx: 437, 437th file is found
# idx: 438, 438th file is found
# idx: 439, 439th file is found
# idx: 440, 440th file is found
# idx: 441, 441th file is found
# idx: 442, 442th file is found
# idx: 443, 443th file is found
# idx: 444, 444th file is found
# idx: 445, 445th file is found
# idx: 446, 446th file is found
# idx: 447, 447th file is found
# idx: 448, 448th file is found
# idx: 449, 449th file is found
# idx: 450, 450th file is found
# idx: 451, 451th file is found
# idx: 452, 452th file is found
# idx: 453, 453th file is found
# idx: 454, 454th file is found
# idx: 455, 455th file is found
# idx: 456, 456th file is found
# idx: 457, 457th file is found
# idx: 458, 458th file is found
# idx: 459, 459th file is found
# idx: 460, 460th file is found
# idx: 461, 461th file is found
# idx: 462, 462th file is found
# idx: 463, 463th file is found
# idx: 464, 464th file is found
# idx: 465, 465th file is found
# idx: 466, 466th file is found
# idx: 467, 467th file is found
# idx: 468, 468th file is found
# idx: 469, 469th file is found
# idx: 470, 470th file is found
# idx: 471, 471th file is found
# idx: 472, 472th file is found
# idx: 473, 473th file is found
# idx: 474, 474th file is found
# idx: 475, 475th file is found
# idx: 476, 476th file is found
# idx: 477, 477th file is found
# idx: 478, 478th file is found
# idx: 479, 479th file is found
# idx: 480, 480th file is found
# idx: 481, 481th file is found
# idx: 482, 482th file is found
# idx: 483, 483th file is found
# idx: 484, 484th file is found
# idx: 485, 485th file is found
# idx: 486, 486th file is found
# idx: 487, 487th file is found
# idx: 488, 488th file is found
# idx: 489, 489th file is found
# idx: 490, 490th file is found
# idx: 491, 491th file is found
# idx: 492, 492th file is found
# idx: 493, 493th file is found
# idx: 494, 494th file is found
# idx: 495, 495th file is found
# idx: 496, 496th file is found
# idx: 497, 497th file is found
# idx: 498, 498th file is found
# idx: 499, 499th file is found
#
# Lets load 500 files!
#  --> Loading 0th file...
#  --> Loading 1th file...
#  --> Loading 2th file...
#  --> Loading 3th file...
#  --> Loading 4th file...
#  --> Loading 5th file...
#  --> Loading 6th file...
#  --> Loading 7th file...
#  --> Loading 8th file...
#  --> Loading 9th file...
#  --> Loading 10th file...
#  --> Loading 11th file...
#  --> Loading 12th file...
#  --> Loading 13th file...
#  --> Loading 14th file...
#  --> Loading 15th file...
#  --> Loading 16th file...
#  --> Loading 17th file...
#  --> Loading 18th file...
#  --> Loading 19th file...
#  --> Loading 20th file...
#  --> Loading 21th file...
#  --> Loading 22th file...
#  --> Loading 23th file...
#  --> Loading 24th file...
#  --> Loading 25th file...
#  --> Loading 26th file...
#  --> Loading 27th file...
#  --> Loading 28th file...
#  --> Loading 29th file...
#  --> Loading 30th file...
#  --> Loading 31th file...
#  --> Loading 32th file...
#  --> Loading 33th file...
#  --> Loading 34th file...
#  --> Loading 35th file...
#  --> Loading 36th file...
#  --> Loading 37th file...
#  --> Loading 38th file...
#  --> Loading 39th file...
#  --> Loading 40th file...
#  --> Loading 41th file...
#  --> Loading 42th file...
#  --> Loading 43th file...
#  --> Loading 44th file...
#  --> Loading 45th file...
#  --> Loading 46th file...
#  --> Loading 47th file...
#  --> Loading 48th file...
#  --> Loading 49th file...
#  --> Loading 50th file...
#  --> Loading 51th file...
#  --> Loading 52th file...
#  --> Loading 53th file...
#  --> Loading 54th file...
#  --> Loading 55th file...
#  --> Loading 56th file...
#  --> Loading 57th file...
#  --> Loading 58th file...
#  --> Loading 59th file...
#  --> Loading 60th file...
#  --> Loading 61th file...
#  --> Loading 62th file...
#  --> Loading 63th file...
#  --> Loading 64th file...
#  --> Loading 65th file...
#  --> Loading 66th file...
#  --> Loading 67th file...
#  --> Loading 68th file...
#  --> Loading 69th file...
#  --> Loading 70th file...
#  --> Loading 71th file...
#  --> Loading 72th file...
#  --> Loading 73th file...
#  --> Loading 74th file...
#  --> Loading 75th file...
#  --> Loading 76th file...
#  --> Loading 77th file...
#  --> Loading 78th file...
#  --> Loading 79th file...
#  --> Loading 80th file...
#  --> Loading 81th file...
#  --> Loading 82th file...
#  --> Loading 83th file...
#  --> Loading 84th file...
#  --> Loading 85th file...
#  --> Loading 86th file...
#  --> Loading 87th file...
#  --> Loading 88th file...
#  --> Loading 89th file...
#  --> Loading 90th file...
#  --> Loading 91th file...
#  --> Loading 92th file...
#  --> Loading 93th file...
#  --> Loading 94th file...
#  --> Loading 95th file...
#  --> Loading 96th file...
#  --> Loading 97th file...
#  --> Loading 98th file...
#  --> Loading 99th file...
#  --> Loading 100th file...
#  --> Loading 101th file...
#  --> Loading 102th file...
#  --> Loading 103th file...
#  --> Loading 104th file...
#  --> Loading 105th file...
#  --> Loading 106th file...
#  --> Loading 107th file...
#  --> Loading 108th file...
#  --> Loading 109th file...
#  --> Loading 110th file...
#  --> Loading 111th file...
#  --> Loading 112th file...
#  --> Loading 113th file...
#  --> Loading 114th file...
#  --> Loading 115th file...
#  --> Loading 116th file...
#  --> Loading 117th file...
#  --> Loading 118th file...
#  --> Loading 119th file...
#  --> Loading 120th file...
#  --> Loading 121th file...
#  --> Loading 122th file...
#  --> Loading 123th file...
#  --> Loading 124th file...
#  --> Loading 125th file...
#  --> Loading 126th file...
#  --> Loading 127th file...
#  --> Loading 128th file...
#  --> Loading 129th file...
#  --> Loading 130th file...
#  --> Loading 131th file...
#  --> Loading 132th file...
#  --> Loading 133th file...
#  --> Loading 134th file...
#  --> Loading 135th file...
#  --> Loading 136th file...
#  --> Loading 137th file...
#  --> Loading 138th file...
#  --> Loading 139th file...
#  --> Loading 140th file...
#  --> Loading 141th file...
#  --> Loading 142th file...
#  --> Loading 143th file...
#  --> Loading 144th file...
#  --> Loading 145th file...
#  --> Loading 146th file...
#  --> Loading 147th file...
#  --> Loading 148th file...
#  --> Loading 149th file...
#  --> Loading 150th file...
#  --> Loading 151th file...
#  --> Loading 152th file...
#  --> Loading 153th file...
#  --> Loading 154th file...
#  --> Loading 155th file...
#  --> Loading 156th file...
#  --> Loading 157th file...
#  --> Loading 158th file...
#  --> Loading 159th file...
#  --> Loading 160th file...
#  --> Loading 161th file...
#  --> Loading 162th file...
#  --> Loading 163th file...
#  --> Loading 164th file...
#  --> Loading 165th file...
#  --> Loading 166th file...
#  --> Loading 167th file...
#  --> Loading 168th file...
#  --> Loading 169th file...
#  --> Loading 170th file...
#  --> Loading 171th file...
#  --> Loading 172th file...
#  --> Loading 173th file...
#  --> Loading 174th file...
#  --> Loading 175th file...
#  --> Loading 176th file...
#  --> Loading 177th file...
#  --> Loading 178th file...
#  --> Loading 179th file...
#  --> Loading 180th file...
#  --> Loading 181th file...
#  --> Loading 182th file...
#  --> Loading 183th file...
#  --> Loading 184th file...
#  --> Loading 185th file...
#  --> Loading 186th file...
#  --> Loading 187th file...
#  --> Loading 188th file...
#  --> Loading 189th file...
#  --> Loading 190th file...
#  --> Loading 191th file...
#  --> Loading 192th file...
#  --> Loading 193th file...
#  --> Loading 194th file...
#  --> Loading 195th file...
#  --> Loading 196th file...
#  --> Loading 197th file...
#  --> Loading 198th file...
#  --> Loading 199th file...
#  --> Loading 200th file...
#  --> Loading 201th file...
#  --> Loading 202th file...
#  --> Loading 203th file...
#  --> Loading 204th file...
#  --> Loading 205th file...
#  --> Loading 206th file...
#  --> Loading 207th file...
#  --> Loading 208th file...
#  --> Loading 209th file...
#  --> Loading 210th file...
#  --> Loading 211th file...
#  --> Loading 212th file...
#  --> Loading 213th file...
#  --> Loading 214th file...
#  --> Loading 215th file...
#  --> Loading 216th file...
#  --> Loading 217th file...
#  --> Loading 218th file...
#  --> Loading 219th file...
#  --> Loading 220th file...
#  --> Loading 221th file...
#  --> Loading 222th file...
#  --> Loading 223th file...
#  --> Loading 224th file...
#  --> Loading 225th file...
#  --> Loading 226th file...
#  --> Loading 227th file...
#  --> Loading 228th file...
#  --> Loading 229th file...
#  --> Loading 230th file...
#  --> Loading 231th file...
#  --> Loading 232th file...
#  --> Loading 233th file...
#  --> Loading 234th file...
#  --> Loading 235th file...
#  --> Loading 236th file...
#  --> Loading 237th file...
#  --> Loading 238th file...
#  --> Loading 239th file...
#  --> Loading 240th file...
#  --> Loading 241th file...
#  --> Loading 242th file...
#  --> Loading 243th file...
#  --> Loading 244th file...
#  --> Loading 245th file...
#  --> Loading 246th file...
#  --> Loading 247th file...
#  --> Loading 248th file...
#  --> Loading 249th file...
#  --> Loading 250th file...
#  --> Loading 251th file...
#  --> Loading 252th file...
#  --> Loading 253th file...
#  --> Loading 254th file...
#  --> Loading 255th file...
#  --> Loading 256th file...
#  --> Loading 257th file...
#  --> Loading 258th file...
#  --> Loading 259th file...
#  --> Loading 260th file...
#  --> Loading 261th file...
#  --> Loading 262th file...
#  --> Loading 263th file...
#  --> Loading 264th file...
#  --> Loading 265th file...
#  --> Loading 266th file...
#  --> Loading 267th file...
#  --> Loading 268th file...
#  --> Loading 269th file...
#  --> Loading 270th file...
#  --> Loading 271th file...
#  --> Loading 272th file...
#  --> Loading 273th file...
#  --> Loading 274th file...
#  --> Loading 275th file...
#  --> Loading 276th file...
#  --> Loading 277th file...
#  --> Loading 278th file...
#  --> Loading 279th file...
#  --> Loading 280th file...
#  --> Loading 281th file...
#  --> Loading 282th file...
#  --> Loading 283th file...
#  --> Loading 284th file...
#  --> Loading 285th file...
#  --> Loading 286th file...
#  --> Loading 287th file...
#  --> Loading 288th file...
#  --> Loading 289th file...
#  --> Loading 290th file...
#  --> Loading 291th file...
#  --> Loading 292th file...
#  --> Loading 293th file...
#  --> Loading 294th file...
#  --> Loading 295th file...
#  --> Loading 296th file...
#  --> Loading 297th file...
#  --> Loading 298th file...
#  --> Loading 299th file...
#  --> Loading 300th file...
#  --> Loading 301th file...
#  --> Loading 302th file...
#  --> Loading 303th file...
#  --> Loading 304th file...
#  --> Loading 305th file...
#  --> Loading 306th file...
#  --> Loading 307th file...
#  --> Loading 308th file...
#  --> Loading 309th file...
#  --> Loading 310th file...
#  --> Loading 311th file...
#  --> Loading 312th file...
#  --> Loading 313th file...
#  --> Loading 314th file...
#  --> Loading 315th file...
#  --> Loading 316th file...
#  --> Loading 317th file...
#  --> Loading 318th file...
#  --> Loading 319th file...
#  --> Loading 320th file...
#  --> Loading 321th file...
#  --> Loading 322th file...
#  --> Loading 323th file...
#  --> Loading 324th file...
#  --> Loading 325th file...
#  --> Loading 326th file...
#  --> Loading 327th file...
#  --> Loading 328th file...
#  --> Loading 329th file...
#  --> Loading 330th file...
#  --> Loading 331th file...
#  --> Loading 332th file...
#  --> Loading 333th file...
#  --> Loading 334th file...
#  --> Loading 335th file...
#  --> Loading 336th file...
#  --> Loading 337th file...
#  --> Loading 338th file...
#  --> Loading 339th file...
#  --> Loading 340th file...
#  --> Loading 341th file...
#  --> Loading 342th file...
#  --> Loading 343th file...
#  --> Loading 344th file...
#  --> Loading 345th file...
#  --> Loading 346th file...
#  --> Loading 347th file...
#  --> Loading 348th file...
#  --> Loading 349th file...
#  --> Loading 350th file...
#  --> Loading 351th file...
#  --> Loading 352th file...
#  --> Loading 353th file...
#  --> Loading 354th file...
#  --> Loading 355th file...
#  --> Loading 356th file...
#  --> Loading 357th file...
#  --> Loading 358th file...
#  --> Loading 359th file...
#  --> Loading 360th file...
#  --> Loading 361th file...
#  --> Loading 362th file...
#  --> Loading 363th file...
#  --> Loading 364th file...
#  --> Loading 365th file...
#  --> Loading 366th file...
#  --> Loading 367th file...
#  --> Loading 368th file...
#  --> Loading 369th file...
#  --> Loading 370th file...
#  --> Loading 371th file...
#  --> Loading 372th file...
#  --> Loading 373th file...
#  --> Loading 374th file...
#  --> Loading 375th file...
#  --> Loading 376th file...
#  --> Loading 377th file...
#  --> Loading 378th file...
#  --> Loading 379th file...
#  --> Loading 380th file...
#  --> Loading 381th file...
#  --> Loading 382th file...
#  --> Loading 383th file...
#  --> Loading 384th file...
#  --> Loading 385th file...
#  --> Loading 386th file...
#  --> Loading 387th file...
#  --> Loading 388th file...
#  --> Loading 389th file...
#  --> Loading 390th file...
#  --> Loading 391th file...
#  --> Loading 392th file...
#  --> Loading 393th file...
#  --> Loading 394th file...
#  --> Loading 395th file...
#  --> Loading 396th file...
#  --> Loading 397th file...
#  --> Loading 398th file...
#  --> Loading 399th file...
#  --> Loading 400th file...
#  --> Loading 401th file...
#  --> Loading 402th file...
#  --> Loading 403th file...
#  --> Loading 404th file...
#  --> Loading 405th file...
#  --> Loading 406th file...
#  --> Loading 407th file...
#  --> Loading 408th file...
#  --> Loading 409th file...
#  --> Loading 410th file...
#  --> Loading 411th file...
#  --> Loading 412th file...
#  --> Loading 413th file...
#  --> Loading 414th file...
#  --> Loading 415th file...
#  --> Loading 416th file...
#  --> Loading 417th file...
#  --> Loading 418th file...
#  --> Loading 419th file...
#  --> Loading 420th file...
#  --> Loading 421th file...
#  --> Loading 422th file...
#  --> Loading 423th file...
#  --> Loading 424th file...
#  --> Loading 425th file...
#  --> Loading 426th file...
#  --> Loading 427th file...
#  --> Loading 428th file...
#  --> Loading 429th file...
#  --> Loading 430th file...
#  --> Loading 431th file...
#  --> Loading 432th file...
#  --> Loading 433th file...
#  --> Loading 434th file...
#  --> Loading 435th file...
#  --> Loading 436th file...
#  --> Loading 437th file...
#  --> Loading 438th file...
#  --> Loading 439th file...
#  --> Loading 440th file...
#  --> Loading 441th file...
#  --> Loading 442th file...
#  --> Loading 443th file...
#  --> Loading 444th file...
#  --> Loading 445th file...
#  --> Loading 446th file...
#  --> Loading 447th file...
#  --> Loading 448th file...
#  --> Loading 449th file...
#  --> Loading 450th file...
#  --> Loading 451th file...
#  --> Loading 452th file...
#  --> Loading 453th file...
#  --> Loading 454th file...
#  --> Loading 455th file...
#  --> Loading 456th file...
#  --> Loading 457th file...
#  --> Loading 458th file...
#  --> Loading 459th file...
#  --> Loading 460th file...
#  --> Loading 461th file...
#  --> Loading 462th file...
#  --> Loading 463th file...
#  --> Loading 464th file...
#  --> Loading 465th file...
#  --> Loading 466th file...
#  --> Loading 467th file...
#  --> Loading 468th file...
#  --> Loading 469th file...
#  --> Loading 470th file...
#  --> Loading 471th file...
#  --> Loading 472th file...
#  --> Loading 473th file...
#  --> Loading 474th file...
#  --> Loading 475th file...
#  --> Loading 476th file...
#  --> Loading 477th file...
#  --> Loading 478th file...
#  --> Loading 479th file...
#  --> Loading 480th file...
#  --> Loading 481th file...
#  --> Loading 482th file...
#  --> Loading 483th file...
#  --> Loading 484th file...
#  --> Loading 485th file...
#  --> Loading 486th file...
#  --> Loading 487th file...
#  --> Loading 488th file...
#  --> Loading 489th file...
#  --> Loading 490th file...
#  --> Loading 491th file...
#  --> Loading 492th file...
#  --> Loading 493th file...
#  --> Loading 494th file...
#  --> Loading 495th file...
#  --> Loading 496th file...
#  --> Loading 497th file...
#  --> Loading 498th file...
#  --> Loading 499th file...

# %%
print("==== shape ====")
print(times_all2.shape)
print(infected_num_all2.shape)

print("")
print("==== params ====")
print(f"network_type: {network_type}")
print(f"N: {N}")
print(f"k_ave: {k_ave}")
print(f"gamma: {gamma}")
print(f"tmax: {tmax}")
print(f"seed: {seed}")
print(f"total_itr: {total_itr2}")

print("")
print("==== meta data ====")
for key, value in meta.items():
    print(f"{key}: {value}")
# Out:
# ==== shape ====
# (3, 1, 61, 5000)
# (3, 1, 61, 5000)
#
# ==== params ====
# network_type: BA
# N: 10000
# k_ave: 6
# gamma: 1.0
# tmax: 2000.0
# seed: 0.0
# total_itr: 5000
#
# ==== meta data ====
# start_time: 2025-09-13 20:12:52
# end_time: 2025-09-14 02:38:02
# duration_seconds: 23110.426
# network_type: ER
# runs_per_batch: 510
# total_runs: 51000
# seed_base: 0
# os_name: Mac OS X
# os_version: 15.3.1
# java_version: 24.0.2
# java_vendor: Homebrew
# cpu_cores: 10
# total_memory_mb: 340
# max_memory_mb: 4096

# %%
test_lamb_idx_list = [0, 2, 10, 20, 30]
test_lamb_idx_list = np.array(test_lamb_idx_list, dtype=int)

lamb_size = len(lamb_values)
lamb_idx_list = []
for i in test_lamb_idx_list:
    if i < lamb_size:
        lamb_idx_list.append(i)

lamb_idx_list = np.array(lamb_idx_list)

# %%
last_I2 = np.zeros((len(rho0List), len(c_list), len(lamb_values2), total_itr))
valid_last_I2 = np.zeros((len(rho0List), len(c_list), len(lamb_values2)))
valid_num2 = np.zeros((len(rho0List), len(c_list), len(lamb_values2)))
for rho0_idx in range(len(rho0List)):
    for c_idx in range(len(c_list)):
        for lamb_idx in range(len(lamb_values2)):
            valid = []
            non_valid = []
            for itr_idx in range(total_itr2):
                if infected_num_all2[rho0_idx, c_idx, lamb_idx, itr_idx].size == 0:
                    print(f"Error: infected_num_all[{rho0_idx}, {c_idx}, {lamb_idx}, {itr_idx}] is None")
                    continue
                I = infected_num_all2[rho0_idx, c_idx, lamb_idx, itr_idx]
                if I > threshold:
                    valid.append(I)
                    valid_num2[rho0_idx, c_idx, lamb_idx] += 1
                else:
                    non_valid.append(I)
            if len(valid) > 0:
                valid_last_I2[rho0_idx, c_idx, lamb_idx] = np.mean(valid)
            else:
                valid_last_I2[rho0_idx, c_idx, lamb_idx] = np.mean(non_valid)

# %%
plot = [valid_last_I, valid_last_I2]
lambs = [lamb_values, lamb_values2]

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 6), sharey=False, squeeze=False)

delta = 0.05

for idx in range(2):
    ax = axes[0, idx]

    for rho0_idx in range(len(rho0List)):
        rho0 = rho0List[rho0_idx]
        valid_mean_I = plot[idx][rho0_idx, c_idx, :]
        print(f"length: valid_mean_I .. {len(valid_mean_I)}, lambs .. {len(lambs[idx])}")
        ax.plot(lambs[idx], valid_mean_I/N, linestyle="-", color=colors[rho0_idx], marker="o", markersize=6, markerfacecolor="none", markeredgecolor=colors[rho0_idx], label=rf"$\rho0={rho0}$")

    # ax.legend()
    ax.grid(True, linestyle=":", alpha=0.5)
    # ax.set_title(rf"$c={c}$")
    ax.set_xlabel(r"$\lambda$")
    ax.xaxis.set_major_locator(MaxNLocator(nbins=5))

fig.tight_layout()

base = "fig"
suf = 0
while os.path.exists(f"{base}_{suf}.png"):
    suf += 1
plt.savefig(f"{base}_{suf}.png", dpi=300)
plt.show()
# Out:
# length: valid_mean_I .. 51, lambs .. 51
# length: valid_mean_I .. 51, lambs .. 51
# length: valid_mean_I .. 51, lambs .. 51
# length: valid_mean_I .. 61, lambs .. 61
# length: valid_mean_I .. 61, lambs .. 61
# length: valid_mean_I .. 61, lambs .. 61

# %%
threshold = 0

last_I = np.zeros((len(rho0List), len(c_list), len(lamb_values), total_itr))
valid_last_I = np.zeros((len(rho0List), len(c_list), len(lamb_values)))
valid_num = np.zeros((len(rho0List), len(c_list), len(lamb_values)))
for rho0_idx in range(len(rho0List)):
    for c_idx in range(len(c_list)):
        for lamb_idx in range(len(lamb_values)):
            valid = []
            non_valid = []
            for itr_idx in range(total_itr):
                if infected_num_all[rho0_idx, c_idx, lamb_idx, itr_idx].size == 0:
                    print(f"Error: infected_num_all[{rho0_idx}, {c_idx}, {lamb_idx}, {itr_idx}] is None")
                    continue
                I = infected_num_all[rho0_idx, c_idx, lamb_idx, itr_idx]
                if I > threshold:
                    valid.append(I)
                    valid_num[rho0_idx, c_idx, lamb_idx] += 1
                else:
                    non_valid.append(I)
            if len(valid) > 0:
                valid_last_I[rho0_idx, c_idx, lamb_idx] = np.mean(valid)
            else:
                valid_last_I[rho0_idx, c_idx, lamb_idx] = np.mean(non_valid)

# %%
fig, axes = plt.subplots(len(c_list), len(lamb_idx_list), figsize=(6 * len(lamb_idx_list), 6 * len(c_list)))

for c_idx, c in enumerate(c_list):
    for l_idx, lamb_idx in enumerate(lamb_idx_list):
        lamb = lamb_values[lamb_idx]
        axes[c_idx, l_idx].hist(I_at_time[c_idx, lamb_idx, :]/N, bins=20)
        axes[c_idx, l_idx].set_title(rf"$c={c}, \lambda={lamb:.2f}$")
        axes[c_idx, l_idx].set_xlabel("I(tmax)")
        axes[c_idx, l_idx].set_ylabel("frequency")

fig.tight_layout()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[17], line 6
#       4 for l_idx, lamb_idx in enumerate(lamb_idx_list):
#       5     lamb = lamb_values[lamb_idx]
# ----> 6     axes[c_idx, l_idx].hist(I_at_time[c_idx, lamb_idx, :]/N, bins=20)
#       7     axes[c_idx, l_idx].set_title(rf"$c={c}, \lambda={lamb:.2f}$")
#       8     axes[c_idx, l_idx].set_xlabel("I(tmax)")
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
lamb_values_for_theory = np.linspace(np.min(lamb_values), np.max(lamb_values), 1000)
theta_all = np.zeros((len(c_list), len(lamb_values_for_theory)))

for cidx, c in enumerate(c_list):
    theta_results = []

    # 各lambdaについてニュートン法でThetaを解く
    for lamb in lamb_values_for_theory:
        if network_type == "RR":
            # 次数のリスト
            deg_list = [k_ave]
            pk = np.array([1.0])

        elif network_type == "ER":
            # 次数のリスト (ポアソン分布が意味を持つ範囲)
            # 平均の3倍+10程度あれば十分
            deg_list = np.arange(0, int(k_ave * 3) + 10)

            # 次数分布 p(k) を計算 (ポアソン分布)
            pk = scipy.stats.poisson.pmf(deg_list, k_ave)

        # elif network_type == "SF":
        #     deg_list = np.arange(1, 1000)

        #     C = (2 - kappa) * k_ave
        #     pk = C * deg_list ** (- kappa)

        else:
            raise ValueError(f"Invalid network type: {network_type}")

        # 初期値は重要。ここでは前のステップの結果を流用すると収束しやすいが、簡単のため固定値から始める
        # 問題によってはTheta=0も根になる（自明な解）ため、0以外の初期値を選ぶ
        solution = newton_method(deg_list, pk, lamb, gamma, c=c)
        
        # 物理的に意味のある解は Theta >= 0
        if solution < 0:
            solution = 0
            
        theta_results.append(solution)
        # print(f"{lamb:.4f}, {solution:.8f}")

    theta_all[cidx, :] = np.array(theta_results)

I_theory = np.zeros((len(c_list), len(lamb_values_for_theory)))
for cidx, c in enumerate(c_list):
    for lamb_idx, lamb in enumerate(lamb_values_for_theory):
        I_theory[cidx, lamb_idx] = theta_to_I(deg_list, pk, lamb, gamma, theta_all[cidx, lamb_idx], c=c)

# %%
fig, axes = plt.subplots(1, len(c_list), figsize=(6 * len(c_list), 6), sharey=True)

for c_idx, c in enumerate(c_list):
    axes[c_idx].plot(lamb_values_for_theory, I_theory[c_idx, :], label="Theory", linestyle="--", linewidth=0.5)
    axes[c_idx].plot(lamb_values, valid_I_at_time[c_idx, :]/N, label="Simulation", linestyle="", marker="o", markersize=6, markerfacecolor="none", markeredgecolor=colors[0])
    axes[c_idx].legend()
    axes[c_idx].grid(True, linestyle=":", alpha=0.5)
    axes[c_idx].set_title(rf"$c={c}$")
    axes[c_idx].set_xlabel(r"$\lambda$")
    axes[c_idx].set_ylabel(rf"$I({time})$")

fig.suptitle(rf"$Network: {network_type}, N={N}, \left<k\right>={k_ave}$")
fig.tight_layout()

plt.show()

# %% [markdown]
# ## time まで

# %%
threshold = -1
time = 80
time_idx = np.zeros((len(c_list), len(lamb_values), total_itr), dtype=int)

for c_idx in range(len(c_list)):
    print(f"c: {c_idx + 1} / {len(c_list)}")
    for l_idx in range(len(lamb_values)):
        is_print_lambda = l_idx % 10 == 0
        if is_print_lambda:
            print(f" -->l: {l_idx} / {len(lamb_values)}")
        for itr_idx in range(total_itr):
            last_time = times_all[c_idx, l_idx, itr_idx][-1]
            if last_time > time:
                time_idx[c_idx, l_idx, itr_idx] = int(np.where(times_all[c_idx, l_idx, itr_idx] <= time)[0][-1])
            else:
                time_idx[c_idx, l_idx, itr_idx] = -1


I_at_time = np.zeros((len(c_list), len(lamb_values), total_itr))
valid_I_at_time = np.zeros((len(c_list), len(lamb_values)))
valid_num = np.zeros((len(c_list), len(lamb_values)))
for c_idx in range(len(c_list)):
    for lamb_idx in range(len(lamb_values)):
        valid = []
        non_valid = []
        for itr_idx in range(len(infected_num_all[c_idx, lamb_idx])):
            I_at_time[c_idx, lamb_idx, itr_idx] = infected_num_all[c_idx, lamb_idx, itr_idx][time_idx[c_idx, lamb_idx, itr_idx]]
            if I_at_time[c_idx, lamb_idx, itr_idx] > threshold:
                valid.append(I_at_time[c_idx, lamb_idx, itr_idx])
                valid_num[c_idx, lamb_idx] += 1
            else:
                non_valid.append(I_at_time[c_idx, lamb_idx, itr_idx])
        if len(valid) > 0:
            valid_I_at_time[c_idx, lamb_idx] = np.mean(valid)
        else:
            valid_I_at_time[c_idx, lamb_idx] = np.mean(non_valid)

fig, axes = plt.subplots(1, len(c_list), figsize=(6 * len(c_list), 6), sharey=True)

for c_idx, c in enumerate(c_list):
    axes[c_idx].plot(lamb_values_for_theory, I_theory[c_idx, :], label="Theory", linestyle="--", linewidth=0.5)
    axes[c_idx].plot(lamb_values, valid_I_at_time[c_idx, :]/N, label="Simulation", linestyle="", marker="o", markersize=6, markerfacecolor="none", markeredgecolor=colors[0])
    axes[c_idx].legend()
    axes[c_idx].grid(True, linestyle=":", alpha=0.5)
    axes[c_idx].set_title(rf"$c={c}$")
    axes[c_idx].set_xlabel(r"$\lambda$")
    axes[c_idx].set_ylabel(rf"$I({time})$")

fig.suptitle(rf"$Network: {network_type}, N={N}, \left<k\right>={k_ave}$")
fig.tight_layout()

plt.show()
# Out:
# c: 1 / 3
#  -->l: 0 / 61
#  -->l: 10 / 61
#  -->l: 20 / 61
#  -->l: 30 / 61
#  -->l: 40 / 61
#  -->l: 50 / 61
#  -->l: 60 / 61
# c: 2 / 3
#  -->l: 0 / 61
#  -->l: 10 / 61
#  -->l: 20 / 61
#  -->l: 30 / 61
#  -->l: 40 / 61
#  -->l: 50 / 61
#  -->l: 60 / 61
# c: 3 / 3
#  -->l: 0 / 61
#  -->l: 10 / 61
#  -->l: 20 / 61
#  -->l: 30 / 61
#  -->l: 40 / 61
#  -->l: 50 / 61
#  -->l: 60 / 61
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
